# %% [markdown]
# <a href="https://colab.research.google.com/github/yatakshisharma921-arch/my-firstt/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
list=[10,20,30,40,50]
print(list)
# Out:
# [10, 20, 30, 40, 50]

# %%
#2
list_1=[1,4,7]
print(list_1)
list_1.append(11)
list_1.remove(1)
print(list_1)
# Out:
# [1, 4, 7]
# [4, 7, 11]

# %%
#3
s=input("Enter a string: ")
print("Reversed words:", ''.join(s.split()[::-1]))
#4
num=[5,8,9,44]
reversed_list=num[::-1]
print("Reversed of list: ", reversed_list)
# Out:
# Enter a string: hello
# Reversed words: hello
# Reversed of list:  [44, 9, 8, 5]

# %%
# Program 4: Reverse a list using slicing
my_list = [1, 2, 3, 4, 5]
reversed_list = my_list[::-1]
print("Original List:", my_list)
print("Reversed List:", reversed_list)
# Out:
# Original List: [1, 2, 3, 4, 5]
# Reversed List: [5, 4, 3, 2, 1]

# %%
#5
a=[1,5,5,66,66,666]
freq={}
for i in a:
    freq[i]=freq.get(i,0)+1
print("Frequency of elements:", freq)
# Out:
# Frequency of elements: {1: 1, 5: 2, 66: 2, 666: 1}

# %%
#6
string=input("Enter a string: ")
vowels="aeiouAEIOU"
count=0

for char in string:
    if char in vowels:
        count += 1

print("Number of vowels:", count)
# Out:
# Enter a string: hello my name isss
# Number of vowels: 5

# %%
#7

string = input("Enter a string: ")
if string == string[::-1]:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
# Out:
# Enter a string: 12345
# The string is not a palindrome.

# %%
#8
import string

text = input("Enter a string: ")
clean_text = ''.join(ch for ch in text if ch not in string.punctuation)
print("String without punctuation:", clean_text)
# Out:
# Enter a string: hello!!! how are you??????
# String without punctuation: hello how are you

# %%
# 9
text = input("Enter a sentence: ")
words = text.split()
longest = max(words, key=len)
print("The longest word is:", longest)
# Out:
# Enter a sentence: python is cool
# The longest word is: python

# %%
# 10
file = open("myfile.txt", "w")
file.write("Hello, this is a new file created using Python!\nWelcome to file handling.")
file.close()
print("File created and content written successfully.")
# Out:
# File created and content written successfully.

# %%
# 11
file = open("myfile.txt", "r")
content = file.read()
print("File Content:\n", content)
file.close()
# Out:
# File Content:
#  Hello, this is a new file created using Python!
# Welcome to file handling.
# This line is appended to the file.

# %%
# 12
file = open("myfile.txt", "a")
file.write("\nThis line is appended to the file.")
file.close()
print("Data appended successfully.")
# Out:
# Data appended successfully.

# %%
# 13
file = open("myfile.txt", "r")
lines = file.readlines()
print("Number of lines in the file:", len(lines))
# Out:
# Number of lines in the file: 3

# %%
# 14
from collections import Counter

file = open("myfile.txt", "r")
words = file.read().split()
word_count = Counter(words)
print("Word frequency:\n", word_count)
file.close()
# Out:
# Word frequency:
#  Counter({'is': 2, 'file': 2, 'to': 2, 'Hello,': 1, 'this': 1, 'a': 1, 'new': 1, 'created': 1, 'using': 1, 'Python!': 1, 'Welcome': 1, 'handling.': 1, 'This': 1, 'line': 1, 'appended': 1, 'the': 1, 'file.': 1})

# %%
# 15
with open("myfile.txt", "r") as file1:
    data = file1.read()

with open("copyfile.txt", "w") as file2:
    file2.write(data)

print("Content copied successfully.")
# Out:
# Content copied successfully.
